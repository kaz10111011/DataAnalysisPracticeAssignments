# %% [markdown]
# # Final Project FP-3:  Descriptive Statistics
#
#
# <br>
# <br>

# %% [markdown]
# ___
#
# # <span style="color:k">Analysis of factors contributing to happiness</span>
#
#
# ### Overview:
#
# * **Name**:  <span>Kazuma MATSUI</span>
# * **Student number**:  <span>0400373532</span>
#
# <br>

# %% [markdown]
# ### Purpose:
#
# * The purpose of this Final Project is to determine factors that contribute to happiness.
# * The key **dependent** variable (DV) is Life evaluation (3-year average).
# * The key **independent** variables(IVs) include:
#     * Log GDP per capita
#     * Social support
#     * Healthy life expectancy
#     * Freedom to make life choices
#     * Generosity
#     * Perceptions of corruption
# * There are one DV and six IVs. The figure has about nine thousand cases.
#
#
# <br>

# %% [markdown]
# ### Dataset source:
# The data come from the [WHR25_Data_Figure_2.1v3](https://view.officeapps.live.com/op/view.aspx?src=https%3A%2F%2Ffiles.worldhappiness.report%2FWHR25_Data_Figure_2.1v3.xlsx%3F_gl%3D1*1x45gye*_gcl_au*MTUwMDM5MjAzLjE3NjE5MTY1Mzc.&wdOrigin=BROWSELINK) dataset from the [World Happiness Report](https://www.worldhappiness.report/data-sharing/)

# %% [markdown]
# ___
#
# ## Descriptive Statistics

# %%
# %%capture
# %run descriptive.ipynb

# %%
display_central_tendency_table(num=1)
display_dispersion_table(num=2)
# Out:
# <br><br><p><span style="font-size: 1.2em;"><b>Table 1</b>: Central tendency summary statistics.</span></p>
#         Happiness    GDP  Social Support  Health  Freedom
# mean        5.452  1.220           1.079   0.543    0.564
# median      5.456  1.264           1.106   0.555    0.571
# mode        5.477  0.000           0.000   0.000    0.000
# <br><br><p><span style="font-size: 1.2em;"><b>Table 2</b>: Dispersion summary statistics.</span></p>
#          Happiness    GDP  Social Support  Health  Freedom
# st.dev.      1.122  0.463           0.355   0.223    0.180
# min          1.364  0.000           0.000   0.000    0.000
# max          7.856  2.209           1.840   1.138    1.018
# range        6.492  2.209           1.840   1.138    1.018
# 25th         4.596  0.901           0.851   0.383    0.450
# 75th         6.295  1.567           1.361   0.705    0.676
# IQR          1.699  0.666           0.510   0.322    0.226

# %%
plot_descriptive()
# Out:
# <p><span style="font-size: 1.2em;"><b>Figure 1</b>: Correlations amongst main variables.</span></p><br><br>

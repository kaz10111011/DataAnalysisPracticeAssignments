# %% [markdown]
# # Final Project FP-6:  Machine learning
#
#
# <br>
# <br>

# %% [markdown]
# ___
#
# ## <span style="color:k">Analysis of factors contributing to happiness</span>
#
#
# ### Overview:
#
# * **Name**:  <span>Kazuma MATSUI</span>
# * **Student number**:  <span>0400373532</span>
#
# <br>

# %% [markdown]
# ### Purpose:
#
# * The purpose of this Final Project is to determine factors that contribute to happiness.
# * The key **dependent** variable (DV) is Life evaluation (3-year average).
# * The key **independent** variables(IVs) include:
#     * Log GDP per capita
#     * Social support
#     * Healthy life expectancy
#     * Freedom to make life choices
#     * Generosity
# * There are one DV and six IVs. The figure has about nine thousand cases.
#
#
# <br>

# %% [markdown]
# ### Dataset source:
# The data come from the [WHR25_Data_Figure_2.1v3](https://view.officeapps.live.com/op/view.aspx?src=https%3A%2F%2Ffiles.worldhappiness.report%2FWHR25_Data_Figure_2.1v3.xlsx%3F_gl%3D1*1x45gye*_gcl_au*MTUwMDM5MjAzLjE3NjE5MTY1Mzc.&wdOrigin=BROWSELINK) dataset from the [World Happiness Report](https://www.worldhappiness.report/data-sharing/)

# %% [markdown]
# ___
#
# ## Descriptive Statistics

# %%
import descriptive as de
import parse_data as pa
import classical as cl
import machine as ma

# %% [markdown]
# #### Multiple regression analysis

# %%
ma.Multiple_regression_analysis(pa.df)
# Out:
# R2: 0.7860478421965843
# GDP               0.227287
# Social Support    0.521895
# Health            0.237136
# Freedom           0.336245
# Generosity       -0.010930
# dtype: float64

# %% [markdown]
# I conducted a multiple regression analysis to explain what contributes to happiness. The results shows that social support has the largest effect.
# Referring to R², this medel explains the data reasonably well.

# %% [markdown]
# ---

# %% [markdown]
# #### Classification Analysis

# %% [markdown]
# Based on the results above, social support, freedom, health, and GDP have relatively large coefficients. Therefore, I'll try to visualize the relationships between happiness and two of these factors, health and social support. These two factors have the different magnitudes of coeffiencts.
# Using machine learning model, I predict whether a country has high or low GDP from the variables.

# %%
ma.machine_learning_analysis(pa.df)
# Out:
# Classification rate (training) of the model using health = 0.8350515463917526
# Classification rate (test) of the model using health   = 0.875
# Classification rate (training) of the model using social support = 0.7835051546391752
# Classification rate (test) of the model using social support    = 0.8541666666666666

# %% [markdown]
# The classification rates on the test data are both reasonably high.
# This indicates that only two key variables( happiness and health or happiness and social support ) predict whether a country has a high or low GDP.
